# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.load("./processed_data/crop_data.npz")
Xtrain = data["Xtrain"]
Ytrain = data["Ytrain"]
Xtest = data["Xtest"]
Ytest = data["Ytest"]
Xtrain.shape
# Out:
# (400, 5)

# %%
# initialize the model
mlp = MLPClassifier(hidden_layer_sizes=(10,), activation='relu', solver='adam', max_iter=100, learning_rate="adaptive", random_state=42, n_iter_no_change=10, verbose=True, warm_start=True)

# Train the model
mlp.fit(Xtrain, Ytrain)
# Out:
# Iteration 1, loss = 12.62865514
# Iteration 2, loss = 12.14692372
# Iteration 3, loss = 11.58444516
# Iteration 4, loss = 10.94390571
# Iteration 5, loss = 10.19544529
# Iteration 6, loss = 9.35831496
# Iteration 7, loss = 8.44186279
# Iteration 8, loss = 7.52426174
# Iteration 9, loss = 6.59192631
# Iteration 10, loss = 5.68692773
# Iteration 11, loss = 4.80297870
# Iteration 12, loss = 4.00078616
# Iteration 13, loss = 3.29296170
# Iteration 14, loss = 2.90725530
# Iteration 15, loss = 2.63465597
# Iteration 16, loss = 2.51334580
# Iteration 17, loss = 2.44973151
# Iteration 18, loss = 2.42249673
# Iteration 19, loss = 2.40698738
# Iteration 20, loss = 2.34939530
# Iteration 21, loss = 2.26989212
# Iteration 22, loss = 2.16084115
# Iteration 23, loss = 2.02589009
# Iteration 24, loss = 1.88731674
# Iteration 25, loss = 1.75240448
# Iteration 26, loss = 1.63438396
# Iteration 27, loss = 1.52105552
# Iteration 28, loss = 1.44222905
# Iteration 29, loss = 1.37995331
# ...

# %%
y_pred = mlp.predict(Xtest)
accuracy = accuracy_score(Ytest, y_pred)

# %%
plt.plot(mlp.loss_curve_)
# plt.plot(mlp.validation_scores_)

# %%
cm = confusion_matrix(Ytest, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(Ytest), yticklabels=np.unique(Ytest))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print("Accuracy:", accuracy_score(Ytest, y_pred))
# Out:
# Accuracy: 0.8811881188118812
