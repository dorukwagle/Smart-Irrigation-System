# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = np.load("./processed_data/crop_data.npz")
Xtrain = data["Xtrain"]
Ytrain = data["Ytrain"]
Xtest = data["Xtest"]
Ytest = data["Ytest"]
Xtrain.shape
# Out:
# (400, 5)

# %%
logreg_model = LogisticRegression(random_state=42, max_iter=100, solver="lbfgs", class_weight="balanced")
logreg_model.fit(Xtrain, Ytrain)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
logreg_predictions = logreg_model.predict(Xtest)

# %%
cm = confusion_matrix(Ytest, logreg_predictions)

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["No Irrigation", "Irrigation"], yticklabels=["No Irrigation", "Irrigation"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
logreg_accuracy = accuracy_score(Ytest, logreg_predictions)
print(f"Logistic Regression Accuracy: {logreg_accuracy:.4f}")
# Out:
# Logistic Regression Accuracy: 0.9109
